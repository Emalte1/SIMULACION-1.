# %% [markdown]
# <a href="https://colab.research.google.com/github/Emalte1/SIMULACION-1./blob/main/SIMULACI%C3%93N_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# RF_EJ1.py - Muestra la simulacion del Ej1, de la respuesta en frecuencia
# JEAC, feb 2025
# !pip install control
import numpy as n # Funciones matem´aticas generales
import matplotlib.pyplot as plt # Funciones de graficaci´on
from control.matlab import * # Funciones equivalentes a Matlab
import control as ct
#definici´on del sistema
num1=n.polymul([10],[1., 3.])
den1=n.polymul([1.,0],n.polymul([1., 2.],[1., 1., 2.]))
sys1= tf(num1, den1)
print(sys1)
# # Bode plot for the system
plt.figure(1,figsize=[6, 4])
#ct.config.defaults[’freqplot.grid’] = True
bode(sys1, logspace(-1, 1), plot=True)
plt.xlabel("Frecuencia (rad/s)")
# Margenes de fase, de ganancia y estabilidad
gm, pm, wcg, wcp = margin(sys1)
print("---------------- Analisis de Estabilidad Relativa --------------")
print("Para el sistema: ")
print(sys1)
print("Frecuencia de corte (rad/s), para Mag = 0 dB: "+str(wcp))
print("Frecuencia de corte (rad/s), para Fase = -pi rad (-180°): "+str(wcg))
print("Margen de ganancia (dB): "+str(20*n.log10(gm)))
print("Margen de fase (°): "+str(pm))
if (20*n.log10(gm)>0 and pm>0):
    print("Sistema estable")
else:
    print("Sistema inestable")
plt.show()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.3/578.3 kB 9.0 MB/s eta 0:00:00
# ...
# <TransferFunction>: sys[0]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#           10 s + 30
#   -------------------------
#   s^4 + 3 s^3 + 4 s^2 + 4 s
# /usr/local/lib/python3.12/dist-packages/control/freqplot.py:454: FutureWarning: bode_plot() return value of mag, phase, omega is deprecated; use frequency_response()
#   warnings.warn(
# ---------------- Analisis de Estabilidad Relativa --------------
# Para el sistema:
# <TransferFunction>: sys[0]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#           10 s + 30
#   -------------------------
#   s^4 + 3 s^3 + 4 s^2 + 4 s
# Frecuencia de corte (rad/s), para Mag = 0 dB: 2.4927704919464317
# Frecuencia de corte (rad/s), para Fase = -pi rad (-180°): 1.3311656067742907
# Margen de ganancia (dB): -17.614845134640394
# Margen de fase (°): -70.92844608634358
# Sistema inestable

# %% [markdown]
# # FT G1 Y G2 CON UNA ENTRADA u(t) =√2cos(5t)

# %%
# RF_1a.py - Simulación del numeral 1.a de SIM_5 (frecuencia ω = 5 rad/s)
# JEAC / Estilo uniforme, Junio 2025

# !pip install control
import numpy as n
import matplotlib.pyplot as plt
from control.matlab import *

# Definición de funciones de transferencia
# G1(s) = 30 / (s + 30)
num1 = [30]
den1 = [1, 30]
sys1 = tf(num1, den1)

# G2(s) = 12 / (s^2 + 4s + 8)
num2 = [12]
den2 = [1, 4, 8]
sys2 = tf(num2, den2)

# Frecuencia de interés
w0 = 5  # rad/s

# Rango de frecuencias para análisis
omega = n.logspace(-1, 2, 500)

# Bode plots
plt.figure(1, figsize=(10, 6))
mag1, phase1, omega1 = bode(sys1, omega, plot=False)
plt.subplot(2, 1, 1)
plt.semilogx(omega1, 20 * n.log10(mag1), label="G1(s)")
plt.axvline(w0, color='r', linestyle='--')
plt.ylabel("Magnitud [dB]")
plt.grid(True)
plt.legend()

plt.subplot(2, 1, 2)
plt.semilogx(omega1, n.degrees(phase1), label="G1(s)")
plt.axvline(w0, color='r', linestyle='--')
plt.xlabel("Frecuencia [rad/s]")
plt.ylabel("Fase [°]")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Repetir para G2
plt.figure(2, figsize=(10, 6))
mag2, phase2, omega2 = bode(sys2, omega, plot=False)
plt.subplot(2, 1, 1)
plt.semilogx(omega2, 20 * n.log10(mag2), label="G2(s)")
plt.axvline(w0, color='r', linestyle='--')
plt.ylabel("Magnitud [dB]")
plt.grid(True)
plt.legend()

plt.subplot(2, 1, 2)
plt.semilogx(omega2, n.degrees(phase2), label="G2(s)")
plt.axvline(w0, color='r', linestyle='--')
plt.xlabel("Frecuencia [rad/s]")
plt.ylabel("Fase [°]")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/control/freqplot.py:454: FutureWarning: bode_plot() return value of mag, phase, omega is deprecated; use frequency_response()
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/control/freqplot.py:454: FutureWarning: bode_plot() return value of mag, phase, omega is deprecated; use frequency_response()
#   warnings.warn(

# %% [markdown]
# # FT G1 Y G2 CON UNA ENTRADA u(t) =2cos(8t)

# %%
# RF_1b.py - Simulación del numeral 1.b de SIM_5 (frecuencia ω = 8 rad/s)
# JEAC / Estilo uniforme, Junio 2025

# !pip install control
import numpy as n
import matplotlib.pyplot as plt
from control.matlab import *

# Definición de funciones de transferencia
# G1(s) = 30 / (s + 30)
num1 = [30]
den1 = [1, 30]
sys1 = tf(num1, den1)

# G2(s) = 12 / (s^2 + 4s + 8)
num2 = [12]
den2 = [1, 4, 8]
sys2 = tf(num2, den2)

# Frecuencia de interés
w0 = 8  # rad/s

# Rango de frecuencias para análisis
omega = n.logspace(-1, 2, 500)

# Bode plots
plt.figure(1, figsize=(10, 6))
mag1, phase1, omega1 = bode(sys1, omega, plot=False)
plt.subplot(2, 1, 1)
plt.semilogx(omega1, 20 * n.log10(mag1), label="G1(s)")
plt.axvline(w0, color='r', linestyle='--')
plt.ylabel("Magnitud [dB]")
plt.grid(True)
plt.legend()

plt.subplot(2, 1, 2)
plt.semilogx(omega1, n.degrees(phase1), label="G1(s)")
plt.axvline(w0, color='r', linestyle='--')
plt.xlabel("Frecuencia [rad/s]")
plt.ylabel("Fase [°]")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Repetir para G2
plt.figure(2, figsize=(10, 6))
mag2, phase2, omega2 = bode(sys2, omega, plot=False)
plt.subplot(2, 1, 1)
plt.semilogx(omega2, 20 * n.log10(mag2), label="G2(s)")
plt.axvline(w0, color='r', linestyle='--')
plt.ylabel("Magnitud [dB]")
plt.grid(True)
plt.legend()

plt.subplot(2, 1, 2)
plt.semilogx(omega2, n.degrees(phase2), label="G2(s)")
plt.axvline(w0, color='r', linestyle='--')
plt.xlabel("Frecuencia [rad/s]")
plt.ylabel("Fase [°]")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/control/freqplot.py:454: FutureWarning: bode_plot() return value of mag, phase, omega is deprecated; use frequency_response()
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/control/freqplot.py:454: FutureWarning: bode_plot() return value of mag, phase, omega is deprecated; use frequency_response()
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt

# Punto 1.a: u(t) = √2 cos(5t), G1(j5) ≈ 0.9865 ∠ -9.46°
A1 = np.sqrt(2)
omega1 = 5
mag1 = 0.9865
fase1_deg = -9.46

# Punto 1.b: u(t) = 2 cos(8t), G1(j8) ≈ 0.9668 ∠ -15°
A2 = 2
omega2 = 8
mag2 = 0.9668
fase2_deg = -15

# Tiempo
t1 = np.linspace(0, 2*np.pi/omega1 * 5, 1000)
t2 = np.linspace(0, 2*np.pi/omega2 * 5, 1000)

# Señales del punto 1.a
u1 = A1 * np.cos(omega1 * t1)
y1 = A1 * mag1 * np.cos(omega1 * t1 + np.deg2rad(fase1_deg))

# Señales del punto 1.b
u2 = A2 * np.cos(omega2 * t2)
y2 = A2 * mag2 * np.cos(omega2 * t2 + np.deg2rad(fase2_deg))

# Gráfica 1.a
plt.figure(figsize=(10, 4))
plt.plot(t1, u1, '--', label='Entrada u(t) – Punto 1.a')
plt.plot(t1, y1, label='Salida y(t) – Punto 1.a')
plt.title('Punto 1.a – Entrada y salida: u(t) = √2 cos(5t)')
plt.xlabel('Tiempo [s]')
plt.ylabel('Amplitud')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Gráfica 1.b
plt.figure(figsize=(10, 4))
plt.plot(t2, u2, '--', label='Entrada u(t) – Punto 1.b')
plt.plot(t2, y2, label='Salida y(t) – Punto 1.b')
plt.title('Punto 1.b – Entrada y salida: u(t) = 2 cos(8t)')
plt.xlabel('Tiempo [s]')
plt.ylabel('Amplitud')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Punto 1.a con G2(s)
A1 = np.sqrt(2)
omega1 = 5
mag1 = 0.457
fase1_deg = -130.6

# Punto 1.b con G2(s)
A2 = 2
omega2 = 8
mag2 = 0.186
fase2_deg = -150.6

# Tiempo para ambas señales
t1 = np.linspace(0, 2*np.pi/omega1 * 5, 1000)
t2 = np.linspace(0, 2*np.pi/omega2 * 5, 1000)

# Señales del punto 1.a (G2)
u1 = A1 * np.cos(omega1 * t1)
y1 = A1 * mag1 * np.cos(omega1 * t1 + np.deg2rad(fase1_deg))

# Señales del punto 1.b (G2)
u2 = A2 * np.cos(omega2 * t2)
y2 = A2 * mag2 * np.cos(omega2 * t2 + np.deg2rad(fase2_deg))

# Gráfica 1.a con G2
plt.figure(figsize=(10, 4))
plt.plot(t1, u1, '--', label='Entrada u(t) – Punto 1.a')
plt.plot(t1, y1, label='Salida y(t) – G2(s)')
plt.title('Punto 1.a – Entrada y salida con G₂(s): u(t) = √2 cos(5t)')
plt.xlabel('Tiempo [s]')
plt.ylabel('Amplitud')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Gráfica 1.b con G2
plt.figure(figsize=(10, 4))
plt.plot(t2, u2, '--', label='Entrada u(t) – Punto 1.b')
plt.plot(t2, y2, label='Salida y(t) – G2(s)')
plt.title('Punto 1.b – Entrada y salida con G₂(s): u(t) = 2 cos(8t)')
plt.xlabel('Tiempo [s]')
plt.ylabel('Amplitud')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Actividad 2

# %%
# Encontrar frecuencias de cruce por 0 dB (ganancia unitaria) y -180° para ambos sistemas

def find_crossing(w, y, level):
    """Encuentra la frecuencia donde y cruza el valor level."""
    for i in range(1, len(y)):
        if (y[i-1] - level) * (y[i] - level) < 0:
            # Interpolación lineal
            w0 = w[i-1]
            w1 = w[i]
            y0 = y[i-1]
            y1 = y[i]
            return w0 + (level - y0) * (w1 - w0) / (y1 - y0)
    return None

# Re-calculate mag and phase arrays to ensure they are not scalars
# (They were overwritten by scalar assignments in previous cells)
mag1, phase1, _ = bode(sys1, omega, plot=False)
mag2, phase2, _ = bode(sys2, omega, plot=False)

# Encuentran los cruces
# 'mag1' and 'mag2' are linear magnitudes, convert to dB for 0 dB crossing
w_gc_10 = find_crossing(omega, 20 * n.log10(mag1), 0)     # Cruce por 0 dB para K=10
w_gc_80 = find_crossing(omega, 20 * n.log10(mag2), 0)     # Cruce por 0 dB para K=80
# 'phase1' is in radians, convert to degrees for -180° crossing
w_pc = find_crossing(omega, n.degrees(phase1), -180)   # Cruce por -180° (fase común para ambos)

# Graficar
plt.figure(figsize=(12, 8))

# Magnitud
plt.subplot(2, 1, 1)
plt.semilogx(omega, 20 * n.log10(mag1), label="K = 10")
plt.semilogx(omega, 20 * n.log10(mag2), label="K = 80", linestyle='--')
plt.axhline(0, color='grey', linestyle=':', linewidth=1)
if w_gc_10:
    plt.axvline(w_gc_10, color='orange', linestyle=':', label=f'ω₁ (K=10) ≈ {w_gc_10:.2f} rad/s')
if w_gc_80:
    plt.axvline(w_gc_80, color='red', linestyle=':', label=f'ω₁ (K=80) ≈ {w_gc_80:.2f} rad/s')
plt.ylabel("Magnitud (dB)")
plt.title("Diagrama de Bode - Magnitud")
plt.grid(True, which="both", linestyle=":")
plt.legend()

# Fase
plt.subplot(2, 1, 2)
plt.semilogx(omega, n.degrees(phase1), label="K = 10")
plt.semilogx(omega, n.degrees(phase2), label="K = 80", linestyle='--')
plt.axhline(-180, color='red', linestyle=':', linewidth=1)
if w_pc:
    plt.axvline(w_pc, color='purple', linestyle=':', label=f'ω₀ ≈ {w_pc:.2f} rad/s')
plt.ylabel("Fase (°)")
plt.xlabel("Frecuencia (rad/s)")
plt.title("Diagrama de Bode - Fase")
plt.grid(True, which="both", linestyle=":")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/control/freqplot.py:454: FutureWarning: bode_plot() return value of mag, phase, omega is deprecated; use frequency_response()
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/control/freqplot.py:454: FutureWarning: bode_plot() return value of mag, phase, omega is deprecated; use frequency_response()
#   warnings.warn(

# %% [markdown]
# # Actividad 3

# %%
# Planta de tanques
G_tanque = tf([0.3188], [1, 1.143, 0.3188])

# Diagrama de Bode
plt.figure()
bode(G_tanque)
plt.title("Bode del Sistema de Tanques")
# Out:
# /usr/local/lib/python3.12/dist-packages/control/freqplot.py:454: FutureWarning: bode_plot() return value of mag, phase, omega is deprecated; use frequency_response()
#   warnings.warn(
# Text(0.5, 1.0, 'Bode del Sistema de Tanques')
